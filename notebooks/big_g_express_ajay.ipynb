# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

faults = pd.read_csv('../data/J1939Faults.csv', low_memory=False, parse_dates=['EventTimeStamp', 'LocationTimeStamp']) #1187335

# %% [markdown]
# ### Big G Express: Predicting Derates
# In this project, you will be working with fault code data and vehicle onboard diagnostic data to try and predict an upcoming full derate. These are indicated by an SPN 5246.
#
# You have been provided with a two files containing the data you will use to make these predictions (J1939Faults.csv and VehicleDiagnosticOnboardData.csv) as well as two files describing some of the contents (DataInfo.docx and Service Fault Codes_1_0_0_167.xlsx)
#
# Note that in its raw form the data does not have "labels", so you must define what labels you are going to use and create those labels in your dataset. Also, you will likely need to perform some significant feature engineering in order to build an accurate predictor.
#
# Additional cleaning tasks:
#
# 1. Remove faults occurring in the vicinity of the service locations at (36.0666667, -86.4347222), (35.5883333, -86.4438888), and (36.1950, -83.174722)
# 2. Remove faults where the EquipmentID has more than 5 characters.

# %%
for lat, lon in [(36.0666667, -86.4347222), (35.5883333, -86.4438888), (36.1950, -83.174722)]:
    
    faults = faults.loc[~((abs(lat - faults['Latitude']) <= 0.01) &
                          (abs(lon - faults['Longitude']) <= 0.01))]

# %%
#Remove faults where the EquipmentID has more than 5 characters.
faults =faults[faults['EquipmentID'].str.len() <= 5] #1185166 rows

# %%
faults
# Out:
#          RecordID     ESS_Id      EventTimeStamp  \
# 0               1     990349 2015-02-21 10:47:13
# 1               2     990360 2015-02-21 11:34:34
# 2               3     990364 2015-02-21 11:35:31
# 3               4     990370 2015-02-21 11:35:33
# 4               5     990416 2015-02-21 11:39:41
# ...           ...        ...                 ...
# 1187330   1248454  123904424 2020-03-06 14:00:26
# 1187331   1248455  123905139 2020-03-06 14:04:23
# 1187332   1248456  123905996 2020-03-06 14:13:38
# 1187333   1248457  123906113 2020-03-06 14:14:13
# 1187334   1248458  123906131 2020-03-06 14:15:34
#
#                                           eventDescription  actionDescription  \
# 0                  Low (Severity Low) Engine Coolant Level                NaN
# 1                                                      NaN                NaN
# 2                      Incorrect Data Steering Wheel Angle                NaN
# 3                      Incorrect Data Steering Wheel Angle                NaN
# 4                                                      NaN                NaN
# ...                                                    ...                ...
# 1187330             Low (Severity Low) Catalyst Tank Level                NaN
# 1187331   Condition Exists Engine Protection Torque Derate                NaN
# 1187332  Abnormal Rate of Change Aftertreatment 1 Intak...                NaN
# 1187333         Low (Severity Medium) Engine Coolant Level                NaN
# 1187334         Low (Severity Medium) Engine Coolant Level                NaN
#
#                                       ecuSoftwareVersion ecuSerialNumber  \
# 0                                                unknown         unknown
# 1                                                unknown         unknown
# 2                                                unknown         unknown
# 3                                                unknown         unknown
# 4                   22281684P01*22357957P01*22362082P01*        13063430
# ...                                                  ...             ...
# 1187330  04384413*22383729*082218154102*60701732*G1*BGT*        80156139
# 1187331  04358814*06099720*030816202706*09400153*G1*BDR*        79932020
# 1187332  05317106*05100987*050719120655*09401585*G1*BDR*        79880653
# 1187333  04384413*22544852*090619141107*60701756*G1*BGT*             NaN
# 1187334  04384413*22544852*090619141107*60701756*G1*BGT*             NaN
#
#                      ecuModel  ecuMake  ecuSource   spn  fmi  active  \
# 0                     unknown  unknown          0   111   17    True
# 1                     unknown  unknown         11   629   12    True
# 2                     unknown  unknown         11  1807    2   False
# 3                     unknown  unknown         11  1807    2    True
# 4        0USA13_13_0415_2238A    VOLVO          0  4364   17   False
# ...                       ...      ...        ...   ...  ...     ...
# 1187330     6X1u17D1500000000    CMMNS          0  1761   17   False
# 1187331     6X1u13D1500000000    CMMNS          0  1569   31    True
# 1187332     6X1u13D1500000000    CMMNS          0  3216   10    True
# 1187333                   NaN      NaN          0   111   18    True
# 1187334                   NaN      NaN          0   111   18   False
#
#          activeTransitionCount  faultValue EquipmentID  MCTNumber   Latitude  \
# 0                            2         NaN        1439  105354361  38.857638
# 1                          127         NaN        1439  105354361  38.857638
# 2                          127         NaN        1369  105336226  41.421250
# 3                          127         NaN        1369  105336226  41.421018
# 4                            2         NaN        1674  105427130  38.416481
# ...                        ...         ...         ...        ...        ...
# 1187330                      3         NaN        2282  105439740  37.094768
# 1187331                      5         NaN        1994  105354084  34.390740
# 1187332                      1         NaN        1850  105336308  34.430370
# 1187333                      8         NaN        2377  108605700  35.030925
# 1187334                      8         NaN        2377  108605700  35.027314
#
#          Longitude   LocationTimeStamp
# 0       -84.626851 2015-02-21 11:34:25
# 1       -84.626851 2015-02-21 11:35:10
# 2       -87.767361 2015-02-21 11:35:26
# 3       -87.767361 2015-02-21 11:36:08
# 4       -89.442638 2015-02-21 11:39:37
# ...            ...                 ...
# 1187330 -85.897407 2020-03-06 14:00:21
# 1187331 -79.461805 2020-03-06 14:04:59
# 1187332 -84.920509 2020-03-06 14:14:14
# 1187333 -85.321527 2020-03-06 14:14:49
# 1187334 -85.323472 2020-03-06 14:15:30
#
# [1053758 rows x 20 columns]

# %%
faults_1569 = faults.loc[(faults['spn'] == 1569) & (faults['fmi'] == 31)]

faults_1569
#faults.loc[faults['spn'] == 5246]
#faults.loc[faults['EquipmentID'] == 1395] #1721

# %%
faults_5246 = faults.loc[faults['spn'] == 5246]
faults_5246
# Out:
#          RecordID     ESS_Id      EventTimeStamp eventDescription  \
# 2089         2090    1011009 2015-02-23 05:05:44              NaN
# 2971         2972    1026305 2015-02-23 15:54:22              NaN
# 5713         5714    1070646 2015-02-25 13:53:08              NaN
# 5809         5810    1071907 2015-02-25 14:47:00              NaN
# 6534         6535    1097942 2015-02-26 22:24:29              NaN
# ...           ...        ...                 ...              ...
# 1179423   1239564  119961467 2020-02-06 08:03:09              NaN
# 1181700   1241841  120905759 2020-02-13 13:32:39              NaN
# 1181717   1241858  120910417 2020-02-13 14:01:40              NaN
# 1181996   1242137  121038018 2020-02-14 11:21:54              NaN
# 1182657   1242798  121404044 2020-02-17 17:08:39              NaN
#
#          actionDescription                               ecuSoftwareVersion  \
# 2089                   NaN  05290170*03015749*051914190353*09400015*G1*BDR*
# 2971                   NaN                                          unknown
# 5713                   NaN                                          unknown
# 5809                   NaN                                          unknown
# 6534                   NaN  04993120*00021657*082113134117*07700053*I0*BBZ*
# ...                    ...                                              ...
# 1179423                NaN  04358814*06005963*051718174436*09401683*G1*BDR*
# 1181700                NaN  04358814*06026985*051718174436*09401683*G1*BDR*
# 1181717                NaN  04358814*06026985*051718174436*09401683*G1*BDR*
# 1181996                NaN                                              NaN
# 1182657                NaN                                              NaN
#
#         ecuSerialNumber           ecuModel  ecuMake  ecuSource   spn  fmi  \
# 2089           79642446  6X1u13D1500000000    CMMNS          0  5246    0
# 2971            unknown            unknown  unknown          0  5246    0
# 5713            unknown            unknown  unknown          0  5246    0
# 5809            unknown            unknown  unknown          0  5246    0
# 6534           79466573  6X1u10D1500000000    CMMNS          0  5246    0
# ...                 ...                ...      ...        ...   ...  ...
# 1179423        79897320  6X1u13D1500000000    CMMNS          0  5246    0
# 1181700        79903054  6X1u13D1500000000    CMMNS          0  5246    0
# 1181717        79903054  6X1u13D1500000000    CMMNS          0  5246    0
# 1181996             NaN                NaN      NaN         49  5246   19
# 1182657             NaN                NaN      NaN         49  5246   19
#
#          active  activeTransitionCount  faultValue EquipmentID  MCTNumber  \
# 2089       True                      1         NaN        1630  105329900
# 2971       True                      1         NaN        1487  105369355
# 5713       True                      1         NaN        1329  105400037
# 5809      False                      1         NaN        1329  105400037
# 6534       True                      1         NaN        1419  105355995
# ...         ...                    ...         ...         ...        ...
# 1179423   False                      1         NaN        1854  105385876
# 1181700    True                      1         NaN        1872  105301976
# 1181717   False                      1         NaN        1872  105301976
# 1181996    True                     88         NaN         302  105418777
# 1182657   False                     88         NaN         302  105418777
#
#           Latitude  Longitude   LocationTimeStamp
# 2089     40.733009 -74.087777 2015-02-23 05:08:23
# 2971     28.077361 -81.897083 2015-02-23 15:54:58
# 5713     39.399583 -82.974768 2015-02-25 13:56:31
# 5809     39.399629 -82.974814 2015-02-25 14:46:56
# 6534     37.596805 -85.865555 2015-02-26 22:25:05
# ...            ...        ...                 ...
# 1179423  35.943472 -83.823240 2020-02-06 08:03:05
# 1181700  35.707268 -81.397037 2020-02-13 13:33:15
# 1181717  35.708101 -81.395648 2020-02-13 13:59:51
# 1181996  38.349490 -85.708425 2020-02-14 11:22:30
# 1182657  38.192175 -85.707546 2020-02-17 17:08:34
#
# [933 rows x 20 columns]

# %%
faults_5246["EquipmentID"].nunique()
# Out:
# 191

# %%
#df1=faults_5246.loc[faults_5246['EquipmentID'] == '1872']

df1 = faults.loc[( faults['EquipmentID'] == '1419')]
df1= df1.loc[(df1['LocationTimeStamp'] > '2016-03-01') ]
df1= df1.loc[(df1['LocationTimeStamp'] <= '2016-04-25') ].sort_values(by=['LocationTimeStamp'])
#df1['spn']
df1.tail(30)
#df1["EquipmentID"].value_counts().to_frame().reset_index().head(30)
# Out:
#         RecordID   ESS_Id      EventTimeStamp  \
# 394113    401614  7752219 2016-03-01 09:40:35
# 396097    403598  7783445 2016-03-02 14:21:48
# 396990    404491  7799478 2016-03-03 09:05:15
# 397073    404574  7801047 2016-03-03 10:10:51
# 397083    404584  7801294 2016-03-03 10:21:06
# 397130    404631  7802206 2016-03-03 10:58:59
# 397252    404753  7804937 2016-03-03 12:43:13
# 397314    404815  7805953 2016-03-03 13:22:14
# 397388    404889  7807126 2016-03-03 14:14:06
# 397447    404948  7808070 2016-03-03 14:49:32
# 397946    405447  7816309 2016-03-04 03:05:32
# 398206    405707  7820069 2016-03-04 07:07:41
# 401117  NaN    NaN                    NaN         NaN         NaN        NaN
# 401322  NaN    NaN                    NaN         NaN         NaN        NaN
# 420823  NaN    NaN                    NaN         NaN         NaN        NaN
# 420893  NaN    NaN                    NaN         NaN         NaN        NaN
# 436676  NaN    NaN                    NaN         NaN         NaN        NaN
# 436812  NaN    NaN                    NaN         NaN         NaN        NaN
# 441415  NaN    NaN                    NaN         NaN         NaN        NaN
# 449001  NaN    NaN                    NaN         NaN         NaN        NaN
# 449022  NaN    NaN                    NaN         NaN         NaN        NaN
# 449049  NaN    NaN                    NaN         NaN         NaN        NaN
# 449131  NaN    NaN                    NaN         NaN         NaN        NaN
#
#         Latitude  Longitude LocationTimeStamp
# 394113       NaN        NaN               NaT
# 396097       NaN        NaN               NaT
# 396990       NaN        NaN               NaT
# 397073       NaN        NaN               NaT
# 397083       NaN        NaN               NaT
# 397130       NaN        NaN               NaT
# 397252       NaN        NaN               NaT
# 397314       NaN        NaN               NaT
# 397388       NaN        NaN               NaT
# 397447       NaN        NaN               NaT
# 397946       NaN        NaN               NaT
# 398206       NaN        NaN               NaT
# 400451       NaN        NaN               NaT
# 401117       NaN        NaN               NaT
# 401322       NaN        NaN               NaT
# 420823       NaN        NaN               NaT
# 420893       NaN        NaN               NaT
# 436676       NaN        NaN               NaT
# 436812       NaN        NaN               NaT
# 441415       NaN        NaN               NaT
# 449001       NaN        NaN               NaT
# 449022       NaN        NaN               NaT
# 449049       NaN        NaN               NaT
# 449131       NaN        NaN               NaT

# %%
faults["actionDescription"].value_counts()

# %%
faults.corr()

# %%
print(faults.columns)

# %%
faults.describe()

# %%
faults.info()
faults.isnull().sum()

# %%
for colname in faults.columns[:19]:
    print('0s in "{variable}": {count}'.format(
        variable=colname,
        count=np.count_nonzero(faults[colname] == 0)))

# %%
faults.boxplot(figsize = [10, 7])
plt.show()

# %%
vdo_data = pd.read_csv('../data/VehicleDiagnosticOnboardData.csv')
vdo_data

# %%
vdo_data.info()

# %%
vdo_data["Value"].value_counts().to_frame().reset_index().head(30)

# %%
fc = pd.read_excel('../data/Service Fault Codes_1_0_0_167.xlsx')
 

dfc = fc.loc[(fc['SPN'] == 3362)]
#fc.loc[( faults['spn'] == '3362')]
dfc
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 1078                      Y                1682       167  Not Mapped
# 2408                      Y                3569       167  Not Mapped
# 2917                      Y                4295       167  Not Mapped
#
#              SID         MID  J1587 FMI   SPN  J1939 FMI J2012 Pcode  \
# 1078  Not Mapped  Not Mapped         11  3362         31  Not Mapped
# 2408  Not Mapped  Not Mapped          7  3362          7  Not Mapped
# 2917  Not Mapped  Not Mapped          5  3362          5  Not Mapped
#
#      Lamp Color Lamp Device  \
# 1078      Amber     Warning
# 2408      Amber     Warning
# 2917      Amber     Warning
#
#                                     Cummins Description  \
# 1078  Aftertreatment 1 Diesel Exhaust Fluid Dosing U...
# 2408  Aftertreatment 1 Diesel Exhaust Fluid Dosing U...
# 2917  Aftertreatment 1 Diesel Exhaust Fluid Dosing U...
#
#                       Algorithm Description
# 1078  Lack of urea or air to the doser unit
# 2408                                    NaN
# 2917                                    NaN

# %%
fc
# Out:
#      Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 0                         Y                 111       167  Not Mapped
# 1                         Y                 112       167  Not Mapped
# 2                         Y                 113       167  Not Mapped
# 3                         Y                 114       167  Not Mapped
# 4                         Y                 115       167         190
# ...                     ...                 ...       ...         ...
# 7119                      Y                9996       167  Not Mapped
# 7120                      Y                9997       167  Not Mapped
# 7121                      Y                9998       167  Not Mapped
# 7122                      Y                9999       167  Not Mapped
# 7123                      Y               12345       167  Not Mapped
#
#              SID         MID  J1587 FMI     SPN  J1939 FMI J2012 Pcode  \
# 0            254           0         12     629         12       P0606
# 1             20         128          7     635          7  Not Mapped
# 2             20         128          3     635          3  Not Mapped
# 3             20         128          4     635          4  Not Mapped
# 4     Not Mapped  Not Mapped          2     612          2       P0008
# ...          ...         ...        ...     ...        ...         ...
# 7119         155           0         11  524286         31  Not Mapped
# 7120         155           0         11  524286         31  Not Mapped
# 7121         155           0         11  524286         31  Not Mapped
# 7122         155           0         11  524286         31  Not Mapped
# 7123         155           0         11  524286         31  Not Mapped
#
#      Lamp Color      Lamp Device  \
# 0           Red  Stop / Shutdown
# 1           Red  Stop / Shutdown
# 2         Amber          Warning
# 3         Amber          Warning
# 4           Red  Stop / Shutdown
# ...         ...              ...
# 7119      Amber          Warning
# 7120      Amber          Warning
# 7121      Amber          Warning
# 7122      Amber          Warning
# 7123      Amber          Warning
#
#                                     Cummins Description  \
# 0     Engine Control Module Critical Internal Failur...
# 1     Engine Timing Actuator Driver Circuit - Mechan...
# 2     Engine Timing Actuator Driver Circuit - Voltag...
# 3     Engine Timing Actuator Driver Circuit - Voltag...
# 4     Engine Magnetic Speed/Position Lost Both of Tw...
# ...                                                 ...
# 7119      Reserved for temporary use - Condition Exists
# 7120      Reserved for temporary use - Condition Exists
# 7121      Reserved for temporary use - Condition Exists
# 7122      Reserved for temporary use - Condition Exists
# 7123  Reserved for Testing 5 digit FC - Condition Ex...
#
#                                   Algorithm Description
# 0     Error internal to the ECM related to memory ha...
# 1     Mechanical failure in the engine timing actuat...
# 2     High signal voltage detected at the engine tim...
# 3     Low voltage detected at the engine timing actu...
# 4     The ECM has detected that the primary and back...
# ...                                                 ...
# 7119                                                NaN
# 7120                                                NaN
# 7121                                                NaN
# 7122                                                NaN
# 7123                                                NaN
#
# [7124 rows x 14 columns]

# %%
all_trucks = faults['EquipmentID'].unique()
partial_derate = faults.loc[(faults['spn'] == 1569) & (faults['fmi'] == 31)]['EquipmentID'].unique()
total_derate = faults.loc[faults['spn'] == 5246]['EquipmentID'].unique()

partial_derate_only = partial_derate[np.isin(partial_derate, total_derate, invert=True)]
total_derate_only = total_derate[np.isin(total_derate, partial_derate, invert=True)]
partial_and_total_derate = np.intersect1d(partial_derate, total_derate)
no_derate = all_trucks[np.isin(all_trucks, partial_derate_only, invert=True) | np.isin(all_trucks, total_derate_only, invert=True)]

# %%
len(all_trucks)

# %%
len(partial_derate)

# %%
len(total_derate)

# %%
faults_spn = faults['spn'].unique()

# %%
pd.DataFrame(total_derate)
